# %% [markdown]
# # gathering data
#
# import necessary packges

# %%
import pandas as pd
import tweepy
import json
import matplotlib.pyplot as plt 
import numpy as np
import requests 
# %matplotlib inline

# %% [markdown]
# ### twitter enhanced archive data set
#
# read the data set and print out the first 5 rows

# %%
twEnArch = pd.read_csv('twitter-archive-enhanced.csv')

# %%
twEnArch.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### image prediction data set
#
# read the data set and print out the first five rows

# %%
imPredictions = pd.read_csv('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv', sep = '\t')

# %%
imPredictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### tweets data set
#
# create an api from tweepy library  then itterate over the tweets ids and write the informations into txt file as json

# %%
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_secret)

# api = tweepy.API(auth, wait_on_rate_limit=True)

# lista = twEnArch['tweet_id']

# exceptions = []

# with open('tweet_json.txt', 'w') as f:
#     for id_tweet in lista: 
#         try:
#             tweet = api.get_status(id_tweet, tweet_mode= 'extended')
#             json.dump(tweet._json, f)
#             f.write("\n")
#         except Exception as e:
#             exceptions.append(id_tweet)
#             print(str(e))

# %% [markdown]
# reading json file and extract infos
#
# creat tweets data frame with `id` `favorite` and `retweet` **count** then print out the fisrt five rows

# %%
temp = pd.read_json('tweet_json.txt', orient='records', lines = True)
tweets = temp[['id','favorite_count', 'retweet_count']]
tweets.head()
# Out:
#                    id  favorite_count  retweet_count
# 0  892420643555336193           39060           8676
# 1  892177421306343426           33457           6373
# 2  891815181378084864           25216           4233
# 3  891689557279858688           42431           8778
# 4  891327558926688256           40588           9558

# %% [markdown]
# # assessing data
#   - ### twEnarch data set
#
#   print out the data set

# %%
twEnArch
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# look for the name columns values and its count

# %%
twEnArch.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Cooper      11
# Oliver      11
# Lucy        11
# Tucker      10
# Penny       10
# Lola        10
# Bo           9
# Winston      9
# the          8
# Sadie        8
# Buddy        7
# an           7
# Bailey       7
# Daisy        7
# Toby         7
# Scout        6
# Leo          6
# Koda         6
# Milo         6
# Oscar        6
# Jax          6
# Stanley      6
# Bella        6
# Jack         6
# Dave         6
# Rusty        6
# Phil         5
#           ...
# Venti        1
# Bloo         1
# Chef         1
# Corey        1
# Newt         1
# Karma        1
# Emma         1
# Oddie        1
# Tedrick      1
# Linus        1
# Poppy        1
# Brian        1
# Mitch        1
# Harvey       1
# Pluto        1
# Tonks        1
# Ito          1
# Monkey       1
# Smiley       1
# Bruiser      1
# Jeffri       1
# Jarvis       1
# Billy        1
# Lizzie       1
# Petrick      1
# Ulysses      1
# Jed          1
# ...

# %% [markdown]
# there are misleading names like a , this , old , etc

# %% [markdown]
# check for duplicated ids

# %%
twEnArch.tweet_id.duplicated().any()
# Out:
# False

# %%
twEnArch.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %% [markdown]
# theres are null values
#
# check for dog stages columns types

# %%
twEnArch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# dog type object type not boolean
#
# check for values not equal to 10

# %%
temp = twEnArch.rating_denominator != 10 
temp.sum()
# Out:
# 23

# %% [markdown]
# check out the text that contains a decimal value like 13.5 or so

# %%
twEnArch[twEnArch.text.str.contains(r"(\d+\.\d*\/\d+)")].text
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# 45      This is Bella. She hopes her smile made you sm...
# 340     RT @dog_rates: This is Logan, the Chow who liv...
# 695     This is Logan, the Chow who lived. He solemnly...
# 763     This is Sophie. She's a Jubilant Bush Pupper. ...
# 1689    I've been told there's a slight possibility he...
# 1712    Here we have uncovered an entire battalion of ...
# Name: text, dtype: object

# %% [markdown]
# there is decimal rating and the numerator column is int instead of float
#
# check out the source column and its structure

# %%
twEnArch.source[0]
# Out:
# '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'

# %% [markdown]
# there are unnecessary infos like <a , nofollow , rel
#
# check out the expanded urls column

# %%
twEnArch.expanded_urls[0]
# Out:
# 'https://twitter.com/dog_rates/status/892420643555336193/photo/1'

# %% [markdown]
# there is the id in the url

# %% [markdown]
# ### 2-tweets data set
#
# print out the tweets data set

# %%
tweets
# Out:
#                       id  favorite_count  retweet_count
# 0     892420643555336193           39060           8676
# 1     892177421306343426           33457           6373
# 2     891815181378084864           25216           4233
# 3     891689557279858688           42431           8778
# 4     891327558926688256           40588           9558
# 5     891087950875897856           20357           3172
# 6     890971913173991426           11935           2113
# 7     890729181411237888           66028          19229
# 8     890609185150312448           27953           4331
# 9     890240255349198849           32165           7552
# 10    890006608113172480           30847           7458
# 11    889880896479866881           27976           5049
# 12    889665388333682689           48372          10238
# 13    889638837579907072           27372           4620
# 14    889531135344209921           15202           2267
# 15    889278841981685760           25465           5535
# ...

# %% [markdown]
# check for duplicates ids

# %%
tweets.id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicated ids
#
# general view of the data set

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2346 entries, 0 to 2345
# Data columns (total 3 columns):
# id                2346 non-null int64
# favorite_count    2346 non-null int64
# retweet_count     2346 non-null int64
# dtypes: int64(3)
# memory usage: 73.3 KB

# %% [markdown]
# there is no issues in this data set

# %% [markdown]
# ### 3-image Predictions data set
#
# print out the imPredections data set

# %%
imPredictions
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# general view of the data set

# %%
imPredictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# there is no issues in this data set

# %% [markdown]
# # assessing summary
#
# ### quality
#
#    **twitter enchanced archive data set twEnArch**
#
#     1- there is decimal rating and the numerator column is int instead of float
#
#     2-  wrong rating numeratores were extracted from the text column
#
#     3- there is no need of column denominator (we add scale to numerator column header )
#
#     4- null values in retweets columns
#
#     5- source column need to reformating
#
#     6- timestamp data type to date
#
#     7- in_replay_to status id and user id columns need to be converted to appropriate data type
#
#     8- breeds of the dog is inaccurate
#
#     9- name columns have null values and misleading values like 'a'
#
# ### tidiness
#
#     1- there are three data sets insead of one master data set
#
#     2- dog type can be represented in one column instead of three
#
# # cleaning

# %% [markdown]
# first creat a copy of the data set before we start cleaning

# %%
twEnArch_orgin = twEnArch.copy()
tweets_orgin = tweets.copy()
imPredictions_orgin = imPredictions.copy()

# %% [markdown]
# **define:**
#
# there is decimal rating and the numerator column is int instead of float
#
# **code:**
#
# convert the column type to float64

# %%
twEnArch.rating_denominator = twEnArch.rating_denominator.astype('float64')

# %% [markdown]
# **test:**

# %%
twEnArch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null float64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# **define:**
#
# wrong rating numeratores were extracted from the text column
#
# i will repreduce the rating from the text using regex
#
# **code:**
#
# calculate the txt rows that contain the decimal values then recalculate its corresponding numerator column

# %%
twEnArch.text.str.contains(r"(\d+\.\d*\/\d+)").sum()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# 6

# %% [markdown]
# 6 value are decimel

# %%
lista = []

for item in  twEnArch[twEnArch.text.str.contains(r"(\d+\.\d*\/\d+)")].text:
    splitted = item.split('/')
    lista.append(splitted[0].split(' ')[-1])
lista
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['13.5', '9.75', '9.75', '11.27', '9.5', '11.26']

# %%
inds = twEnArch[twEnArch.text.str.contains(r"(\d+\.\d*\/\d+)")].index
for i in range(len(lista)):
    twEnArch.rating_denominator[inds[i]] = lista[i]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **test**:

# %%
twEnArch[twEnArch.text.str.contains(r"(\d+\.\d*\/\d+)")].rating_denominator
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# 45      13.50
# 340      9.75
# 695      9.75
# 763     11.27
# 1689     9.50
# 1712    11.26
# Name: rating_denominator, dtype: float64

# %% [markdown]
# **define:**
#
# there is no need of column denominator (we add scale to numerator column header
#
# **code:**
#
# drop denominator column and and add scale 10 to numerator column

# %%
twEnArch.rename(columns={'rating_numerator':'rating_scale_10'},inplace = True)
twEnArch = twEnArch.drop('rating_denominator',axis = 1)

# %% [markdown]
# **test:**

# %%
twEnArch.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# **define:**
#
# null values in columns retweets so we drop them scince we do not need them, thus the analysis will be at the orgin tweets
#
# **code:**

# %%
twEnArch.drop(['retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'],axis = 1 , inplace = True )

# %% [markdown]
# **test:**

# %%
twEnArch.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# ...

# %% [markdown]
# **define:**
#
# source column need to human readable so i will extract info from its text
#
# **code:**
#
# split the txt and get the info

# %%
twEnArch.source[0]
# Out:
# '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'

# %%
twEnArch.source = twEnArch.source.str.split('>').str[1].str.split('<').str[0]

# %% [markdown]
# **test:**

# %%
twEnArch.source.sample(8)
# Out:
# 1193     Twitter for iPhone
# 374      Twitter for iPhone
# 1459     Twitter for iPhone
# 1820     Twitter for iPhone
# 1925     Twitter for iPhone
# 672     Vine - Make a Scene
# 541      Twitter for iPhone
# 605      Twitter for iPhone
# Name: source, dtype: object

# %% [markdown]
# **define:**
#
# timestamp column dtype need to be date
#
# **code:**

# %%
twEnArch.timestamp = pd.to_datetime(twEnArch.timestamp)

# %% [markdown]
# **test:**

# %%
twEnArch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2356 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2356 non-null datetime64[ns]
# source                   2356 non-null object
# text                     2356 non-null object
# expanded_urls            2297 non-null object
# rating_scale_10          2356 non-null int64
# name                     2356 non-null object
# doggo                    2356 non-null object
# floofer                  2356 non-null object
# pupper                   2356 non-null object
# puppo                    2356 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 239.4+ KB

# %% [markdown]
# **define:**
#
# inreply to status id and inrepaly to use id need to be in string format
#
# or convert it from exp format to int format
#
# **code:**
#
# convert it from exp format to int format  using map function

# %%
twEnArch.in_reply_to_status_id= twEnArch.in_reply_to_status_id.map(lambda x : '{:.0f}'.format(x))
twEnArch.in_reply_to_user_id= twEnArch.in_reply_to_user_id.map(lambda x : '{:.0f}'.format(x))

# %% [markdown]
# **test:**

# %%
twEnArch[twEnArch.in_reply_to_status_id != 'nan'].in_reply_to_status_id
# Out:
# 30      886266357075128320
# 55      881607037314052096
# 64      879553827334172672
# 113     870726202742493184
# 148     863425645568774144
# 149     667152164079423488
# 179     857156678055342080
# 184     855818117272018944
# 186     856286004109553664
# 188     855861584463351808
# 189     855858535607001088
# 218     850328818778820608
# 228     848212111729840128
# 234     847606175596138496
# 251     759099523532779520
# 274     840698300298862592
# 290     838145498691194880
# 291     838085539362402304
# 313     835245984028504064
# 342     832087547559997440
# 346     831903044224835584
# 387     826598365270007808
# 409     823326389336244224
# 427     821152592717697024
# 498     813127251579564032
# 513     811627233043480576
# 565     733109485275860992
# 570     801854330672447488
# 576     800857954417262592
# 611     797123751162839040
#                ...
# 1479    693572215938367488
# 1497    692417313023332352
# 1501    692041934689402880
# ...

# %% [markdown]
# **define:**
#
# we can usse just one column instead of three to represent the dog type
#
# **code:**
#
# by using melt function we melt four dog types columns

# %%
melt = twEnArch.loc[ :, 'doggo' : 'puppo']
remain =  twEnArch.loc[:, 'tweet_id': 'name']


temp = pd.melt(twEnArch, id_vars = remain, value_vars =melt, 
                         var_name = 'stages', value_name = 'dog_stage')
temp = temp.drop('stages', axis = 1)

# %% [markdown]
# **Test:**

# %%
temp
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 0     892420643555336193                   nan                 nan
# 1     892177421306343426                   nan                 nan
# 2     891815181378084864                   nan                 nan
# 3     891689557279858688                   nan                 nan
# 4     891327558926688256                   nan                 nan
# 5     891087950875897856                   nan                 nan
# 6     890971913173991426                   nan                 nan
# 7     890729181411237888                   nan                 nan
# 8     890609185150312448                   nan                 nan
# 9     890240255349198849                   nan                 nan
# 10    890006608113172480                   nan                 nan
# 11    889880896479866881                   nan                 nan
# 12    889665388333682689                   nan                 nan
# ...

# %% [markdown]
# check for the duplicates after melting

# %%
temp.tweet_id.duplicated().sum()
# Out:
# 7068

# %% [markdown]
# there are 7068 duplicated ids so i remove them and keep the last one  after sorting

# %%
temp =temp.sort_values('dog_stage').drop_duplicates('tweet_id', keep = 'last')

# %%
temp.tweet_id.duplicated().sum()
# Out:
# 0

# %%
twEnArch = temp

# %% [markdown]
# **define:**
#
# breeds columns have inaccurate predictions by neural network
#
# p1,p2,p3 columns need to be categorical type for easy analysis
#
# **code:**
#
# i will extract the accurate predictions

# %%
temp = imPredictions.query('p1_dog == True or p2_dog == True or p3_dog== True ')
imPredictions.shape , temp.shape
# Out:
# ((2075, 12), (1751, 12))

# %% [markdown]
# then convert p1 ,p2 and p3 columns to catergorical data type

# %%
imPredictions = temp 
imPredictions[['p1','p2','p3']] = imPredictions[['p1','p2','p3']].apply(lambda x : x.astype('category'))
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:2352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# **test:**

# %%
imPredictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
imPredictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id    1751 non-null int64
# jpg_url     1751 non-null object
# img_num     1751 non-null int64
# p1          1751 non-null category
# p1_conf     1751 non-null float64
# p1_dog      1751 non-null bool
# p2          1751 non-null category
# p2_conf     1751 non-null float64
# p2_dog      1751 non-null bool
# p3          1751 non-null category
# p3_conf     1751 non-null float64
# p3_dog      1751 non-null bool
# dtypes: bool(3), category(3), float64(3), int64(2), object(1)
# memory usage: 146.5+ KB

# %%
imPredictions.p1.nunique()
# Out:
# 215

# %% [markdown]
# **define:**
#
# name column have misleading values like a and null values
#
# **code:**
#
# groupby name and print out the values to see the misleading names like a, an and so forth

# %%
twEnArch.groupby('name').size().sort_values(ascending=False)
# Out:
# name
# None         745
# a             55
# Charlie       12
# Oliver        11
# Lucy          11
# Cooper        11
# Lola          10
# Tucker        10
# Penny         10
# Bo             9
# Winston        9
# Sadie          8
# the            8
# an             7
# Toby           7
# Daisy          7
# Bailey         7
# Buddy          7
# Leo            6
# Scout          6
# Bella          6
# Dave           6
# Rusty          6
# Jack           6
# Jax            6
# Milo           6
# Koda           6
# Stanley        6
# Oscar          6
# very           5
#             ...
# Jiminus        1
# Jimbo          1
# Jim            1
# Jett           1
# Jessiga        1
# Jessifer       1
# Spencer        1
# Jersey         1
# Josep          1
# Juckson        1
# Kellogg        1
# Julio          1
# Sonny          1
# Keet           1
# Kayla          1
# Kawhi          1
# Katie          1
# Kathmandu      1
# Karma          1
# Karll          1
# Karl           1
# ...

# %% [markdown]
# valeus like
#
# `none`
#
# `a`
#
# `an`
#
# `the`
#
# print out the text the the corresponding name value is None to see if there is possible way to extract the name again

# %%
for i in twEnArch.query('name == "None"').text:
    print(i,'\n\n\n')
# Out:
# RT @dogratingrating: Exceptional talent. Original humor. Cutting edge, Nova Scotian comedian. 12/10 https://t.co/uarnTjBeVA
#
#
#
# RT @dogratingrating: Unoriginal idea. Blatant plagiarism. Curious grammar. -5/10 https://t.co/r7XzeQZWzb
#
#
#
# Never seen dog like this. Breathes heavy. Tilts head in a pattern. No bark. Shitty at fetch. Not even cordless. 1/10 https://t.co/i9iSGNn3fx
#
#
#
# What a dog to start the day with. Very calm. Likes to chill by pond. Corkscrews sticking out of head. Obedient. 7/10 https://t.co/0nIxPTDWAZ
#
#
#
# Another topnotch dog. His name is Big Jumpy Rat. Massive ass feet. Superior tail. Jumps high af. 12/10 great pup https://t.co/seESNzgsdm
#
#
#
# This a Norwegian Pewterschmidt named Tickles. Ears for days. 12/10 I care deeply for Tickles https://t.co/0aDF62KVP7
#
#
#
# Two dogs in this one. Both are rare Jujitsu Pythagoreans. One slightly whiter than other. Long legs. 7/10 and 8/10 https://t.co/ITxxcc4v9y
#
#
#
# ...

# %% [markdown]
# I decided to extract the dog names from the text columns to replace the missing values and correct the incorrect dog names. The valied dog names start with upper-case letters.
#
# I collect some of the cases and expressions when the dog names occur in the text column in the following context:
#     - ... named [Dog Name]
#     - meet [Dog Name]
#     - .. name is [Dog Name]
#     - This is [Dog Name]
#     - Say hello to [Dog Name]
#     - Meet [Dog Name]
#     - Here we have [Dog Name]
#     - Here is [Dog Name]
#
# Then I will iterate through the text column and change the value in the name column based on the text column.

# %%
import re

# Creating two lists: one for the names we can' extract and one for the new names
names_clean = []
missing_names = []

# Creating a lit of the texts
text_list = twEnArch['text'].values.tolist()

# Creating a regex pattern
pattern = re.compile('([A-Z].*)')

# Iterating thourgh the text list and check if the content and pattern correspond to some of the extressions
for text in twEnArch['text']:
    
    if text.__contains__('This is') and pattern.fullmatch(text.split()[text.split().index("is")+1]):
        names_clean.append(text.split(" ")[2].strip('.').strip(','))
    elif text.startswith("Meet") and pattern.fullmatch(text.split(" ")[1]):
        names_clean.append(text.split(" ")[1].strip('.').strip(','))
    elif text.startswith("Here we have") and pattern.fullmatch(text.split(" ", 3)[3]):
        names_clean.append(text.split(" ")[3].strip('.').strip(','))
    elif text.split(" ").__contains__("named") and pattern.fullmatch(text.split()[text.split().index("named")+1]):
        names_clean.append(text.split()[text.split().index("named")+1].strip('.').strip(','))
    elif text.__contains__("name is") and pattern.fullmatch(text.split()[text.split().index("is")+1]):
        names_clean.append(text.split()[text.split().index("is")+1].strip('.').strip(','))
    elif text.__contains__("Say hello to") and pattern.fullmatch(text.split()[text.split().index("to")+1]):
        names_clean.append(text.split(" ")[3].strip('.').strip(','))
    else:
        names_clean.append("NaN")
        missing_names.append(text)

# %%
len(names_clean) ,len(missing_names)
# Out:
# (2356, 842)

# %% [markdown]
# print out hte missing names to see it

# %%
missing_names
# Out:
# ['RT @dogratingrating: Exceptional talent. Original humor. Cutting edge, Nova Scotian comedian. 12/10 https://t.co/uarnTjBeVA',
#  'RT @dogratingrating: Unoriginal idea. Blatant plagiarism. Curious grammar. -5/10 https://t.co/r7XzeQZWzb',
#  'Never seen dog like this. Breathes heavy. Tilts head in a pattern. No bark. Shitty at fetch. Not even cordless. 1/10 https://t.co/i9iSGNn3fx',
#  'Here is George. George took a selfie of his new man bun and that is downright epic. (Also looks like Rand Paul) 9/10 https://t.co/afRtVsoIIb',
#  'What a dog to start the day with. Very calm. Likes to chill by pond. Corkscrews sticking out of head. Obedient. 7/10 https://t.co/0nIxPTDWAZ',
#  'Two dogs in this one. Both are rare Jujitsu Pythagoreans. One slightly whiter than other. Long legs. 7/10 and 8/10 https://t.co/ITxxcc4v9y',
#  'Wow. Armored dog here. Ready for battle. Face looks dangerous. Not very loyal. Lil dog on back havin a blast. 5/10 https://t.co/SyMoWrp368',
# ...

# %% [markdown]
# replace this with Nan value

# %%
twEnArch.name = names_clean
#replace This with nan 
twEnArch.loc[twEnArch.name == "This",'name'] = 'NaN'

# %% [markdown]
# **Test:**
#
# compare after cleaning

# %%
twEnArch.groupby('name').size().sort_values(ascending=False)
# Out:
# name
# NaN               929
# Lucy               11
# Charlie            11
# Cooper             10
# Oliver             10
# Tucker              9
# Penny               9
# Sadie               8
# Winston             8
# Lola                8
# Daisy               7
# Bailey              6
# Bella               6
# Koda                6
# hello               6
# Toby                6
# Stanley             6
# Oscar               6
# Jax                 6
# Bo                  6
# Chester             5
# Scout               5
# Milo                5
# Louis               5
# Bentley             5
# Leo                 5
# Rusty               5
# Buddy               5
# Cassie              4
# Reggie              4
#                  ...
# Lucia               1
# Lorelei             1
# Loomis              1
# Longfellow          1
# Marvin              1
# Mary                1
# Mason               1
# Mattie              1
# Mona                1
# Molly               1
# ...

# %% [markdown]
# **define:**
#  ther are three data sets instead of one master data set
#
#  **code:**
#
#  using merge function and join the three data sets by left join on tweet id , id

# %%
df = pd.merge(left= twEnArch, right=imPredictions, left_on='tweet_id', right_on='tweet_id',how='left')

# %%
df = pd.merge(left=df , right= tweets, left_on='tweet_id', right_on='id',how='left')

# %%
df = df.drop('id',axis=1)

# %%
df.head()
# Out:
#              tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 0  667550904950915073                   nan                 nan
# 1  667550882905632768                   nan                 nan
# 2  667549055577362432                   nan                 nan
# 3  667546741521195010                   nan                 nan
# 4  667544320556335104                   nan                 nan
#
#             timestamp              source  \
# 0 2015-11-20 03:51:52  Twitter Web Client
# 1 2015-11-20 03:51:47  Twitter Web Client
# 2 2015-11-20 03:44:31  Twitter Web Client
# 3 2015-11-20 03:35:20  Twitter Web Client
# 4 2015-11-20 03:25:43  Twitter Web Client
#
#                                                 text  \
# 0  RT @dogratingrating: Exceptional talent. Origi...
# 1  RT @dogratingrating: Unoriginal idea. Blatant ...
# 2  Never seen dog like this. Breathes heavy. Tilt...
# 3  Here is George. George took a selfie of his ne...
# ...

# %%
twEnArch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 2259 to 7236
# Data columns (total 10 columns):
# tweet_id                 2356 non-null int64
# in_reply_to_status_id    2356 non-null object
# in_reply_to_user_id      2356 non-null object
# timestamp                2356 non-null datetime64[ns]
# source                   2356 non-null object
# text                     2356 non-null object
# expanded_urls            2297 non-null object
# rating_scale_10          2356 non-null int64
# name                     2356 non-null object
# dog_stage                2356 non-null object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 202.5+ KB

# %% [markdown]
# # analyzing and visualization
#
# print out the columns so that i will see which columns i can use for visualiztion

# %%
df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_scale_10', 'name',
#        'dog_stage', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'favorite_count',
#        'retweet_count'],
#       dtype='object')

# %% [markdown]
# this are the most columns will be important for visualizations
#
# `timestamp `
#
# `dog_stage `
#
# `P's`
#
# `counts`

# %% [markdown]
# # what is the most loved stage

# %% [markdown]
# get the highest 10 categorical values of the p1 column and its corresponding favorite count value

# %%
fav = df.groupby('p1')['favorite_count'].sum().reset_index()
fav= fav.sort_values('favorite_count',ascending=False).head(10)
fav
# Out:
#                      p1  favorite_count
# 124    golden_retriever       1691197.0
# 40   Labrador_retriever       1107532.0
# 53             Pembroke       1000119.0
# 19            Chihuahua        685212.0
# 59              Samoyed        535489.0
# 27       French_bulldog        478876.0
# 103                chow        409855.0
# 164                 pug        315622.0
# 105      cocker_spaniel        311347.0
# 54           Pomeranian        304466.0

# %%
plt.figure(figsize=(10,10))
plt.barh(fav.p1, fav.favorite_count)
plt.title('most loved dog')
plt.xlabel('fav count')
plt.ylabel('breeds')
# Out:
# Text(0,0.5,'breeds')

# %% [markdown]
# the golden_retriever stage is the most loved one and then the labrador_retriever then pembroke

# %% [markdown]
# # what is the change of the golden_retriever  fav count over time (year)
#
# i will extract the year and month from the timestamp column

# %%
df.timestamp = df.timestamp.astype('str')

df['year'] = df.timestamp.apply(lambda x : x.split('-')[0])
df['month'] = df.timestamp.apply(lambda x : x.split('-')[1])

df.head()
# Out:
#              tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 0  667550904950915073                   nan                 nan
# 1  667550882905632768                   nan                 nan
# 2  667549055577362432                   nan                 nan
# 3  667546741521195010                   nan                 nan
# 4  667544320556335104                   nan                 nan
#
#              timestamp              source  \
# 0  2015-11-20 03:51:52  Twitter Web Client
# 1  2015-11-20 03:51:47  Twitter Web Client
# 2  2015-11-20 03:44:31  Twitter Web Client
# 3  2015-11-20 03:35:20  Twitter Web Client
# 4  2015-11-20 03:25:43  Twitter Web Client
#
#                                                 text  \
# 0  RT @dogratingrating: Exceptional talent. Origi...
# 1  RT @dogratingrating: Unoriginal idea. Blatant ...
# 2  Never seen dog like this. Breathes heavy. Tilt...
# 3  Here is George. George took a selfie of his ne...
# ...

# %% [markdown]
# group by year and p1 columns

# %%
temp = df.groupby(['year','p1']).sum().favorite_count.reset_index()
temp = temp.query('p1 == "golden_retriever"')

plt.figure(figsize=(10,5))
plt.plot(temp.year, temp.favorite_count);
plt.title('favorite count over yeaer for golden retriever stage');
plt.xlabel('year');
plt.ylabel('fav count');

# %% [markdown]
# fav count increased by 800000 from 2015 to 2016 then decreased a littel bit
#
# group by month and year for the golden_retriever

# %%
temp = df.query('p1 == "golden_retriever"')
temp = temp.groupby(['year','month']).favorite_count.sum()
temp
ax = temp.plot(kind='bar',title='golden retriever stage favorite count over time',figsize=(10,5))

ax.set_ylabel('fav count')
# Out:
# Text(0,0.5,'fav count')

# %% [markdown]
# the fav count tend to be increase over time
#
# drop year and month columns

# %%
df = df.drop(['year','month'],axis=1)

# %% [markdown]
# # dog stages and its rating

# %%
temp = df.query('dog_stage != "None"')
temp = temp.groupby('dog_stage').rating_scale_10.mean().reset_index()
temp
# Out:
#   dog_stage  rating_scale_10
# 0     doggo        11.879518
# 1   floofer        11.800000
# 2    pupper        10.871595
# 3     puppo        12.133333

# %%
plt.pie(temp.rating_scale_10,labels=temp.dog_stage,radius=2,autopct='%0.1f%%',explode=[0,0,0,0.35],shadow=True);

# %% [markdown]
# puppo has the largest rating by 26.0
#
# # conclusion

# %% [markdown]
# We got some interesting finding related to the Twitter account WeRateDogs. Some conclusions supported our
# assumptions and correspond our daily experiences, for example golden retrievers are very popular all over the world
#
# and puppo stage is the most stage has higher reating  and the rating for golden retriever over time tend to be increasing

# %% [markdown]
# # storing cleaned data

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///college.db', echo = False)
df.to_sql('master', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-f1875b4d5b7b> in <module>()
#       1 from sqlalchemy import create_engine
#       2 engine = create_engine('sqlite:///college.db', echo = False)
# ----> 3 df.to_sql('master', engine, index=False)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1360         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1361                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1362                    chunksize=chunksize, dtype=dtype)
#    1363
#    1364     def to_pickle(self, path, compression='infer'):
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
# ...
